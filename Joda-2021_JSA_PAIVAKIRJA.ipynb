# %% [markdown]
#
#
# ## Johdanto datatieteeseen, TLO-32410
#
# ## Oppimispäiväkirja, Jussi Salakka, oppilasnro. 150044466
#
# _______________________________________________________________________________________________________________________________
#
# # VIIKKO 1
#
# ### Ti 09.03.2021______________________________________________________________________
#
#
#
# ### 1.     Osallistuin luennolle ja keräsin aineiston luennolta sekä webbilinkeistä jota luennolla jaettiin. Kuuntelin perjantain harjoitukset.
#
#
#
# ### 2.       Tiivistelmä luennosta
# ### Aiheena:Johdatus datatieteeseen
#
#
#
# Datatiede on pitkälti käytännön osaamista vaativa työ, ns.”käsityöläisammatti”.
#
# <b>Datatieteilijä Venn Diagrammissa</b>
#
# Yhdistää neljää erillistä toimialuetta ja on näiden keskiössä. Datatieteen asiantuntijoilla on näistä kaikista neljästä osa-alueesta tuntemusta.
#
# =>  Communication, Statistics, Programming, Business
#
#
#  Datatieteilijä Venn Diagrammissa. (Web-lähde: https://whatsthebigdata.com/2016/07/08/the-new-data-scientist-venn-diagram/)
#
#
#
# <b>Datatiede</b>
#
# Datatieteessä yhdistyvät ohjelmointi, datan keräämisen automatisointi ja tilastotiede tulosten käsittelyssä. R-kieli on painottunut nimenomaan datatieteeseen. Python tullut nykyään voimakkaasti datatieteen työkaluksi.
#
# Crisp-DM on prosessi joka kehitettiin jo 1996 kuvaamaan tiedonlouhintaa (data mining). Tiedonlouhinta käsittää tietojen kyselyä tietokannoista ja sen hyödyntämistä päätöksenteossa. Kuvassa ulompi kehä kuvaa tiedonlouhinnan syklistä toimitapaa. Prosessi on jaettu kuuteen vaiheeseen. Crisp-DM on laajasti käytössä ja ainoa heikkous sillä on että se ei kuvaa projektin hallintaa.
#
#
# CRISP-DM-malli esittelee avoimen standardin prosessikuvauksen datatieteestä (Web-lähde: https://en.wikipedia.org/wiki/Cross-industry_standard_process_for_data_mining).
#
#
#
# <b>Data engineering vs. data science.</b>
#
# Data engineering tarkoittaa datan käsittelyn ja analysoinnin käytännön menetelmiä. Data engineer on erikoistunut datan käsittelyyn ja rakentamaan datalle joustavan virran. Datatieteilijät taas osaavat tulkita tietoa ja valita oikeat menetelmät datan käsittelyyn, datatieteilijällä on syvempi käsitys datan tulkinnasta ja menetelmistä. Datatieteilijän tehtävänä on löytää arvo datasta. (https://www.datasciencecentral.com/profiles/blogs/data-scientist-versus-data-engineer)
#
#
#
# <b>Big data</b>
#
# Maailmassa on 163 Zetabittiä dataa mutta data ei ole käytettävissä kaikilla. Merkittävän osan datasta omistavat sellaiset toimijat kuten Google, Facebook jne. Dataa on tarjolla nykyään paljolti pilvessä. Big dataa kuvataan kolmen V:n termillä. Ensimmäinen eli “Volume” kuvaa tietomassaa, toinen ”Velocity” kuvaa nopeutta jolla uutta tietoa syntyy ja kolmas ”Variety” kuvaa että tietoa syntyy hyvin monista lähteistä ja monissa formaateissa.
#
# Big data = volume, velocity, variety
#
#
#
# <b>Ympäristöjä</b>
#
# Alla listaus Python kirjastoista joita luennolla käytettiiin sekä joita voisi ihan ensimmäisenä asentaa:
#
# ·         Gapminder, Pandas, Plotly express, Streamlit
#
# ·         Matplotlib, Numpy
#
#
#
# Kaggle on avoin tietokanta josta voi ladata itseä mielenkiintoisia datasettejä sekä saada opastusta datan käsittelyyn. Tietokanta vaatii kirjautumisen mutta sen voi tehdä esim. Google tunnuksilla.
#
#
# Netflix otsikot. (Web-lähde: https://www.kaggle.com/shivamb/netflix-shows)
#
#
#
# ### Pe 12.03.2021______________________________________________________________________
#
# Harjoituksessa tutustuttiin Pandas dataframe komentoihin ja kuinka esim. CSV tiedostoja luetaan dataframeen.
#
# Harjoituksessa käsiteltiin dataframe luettelojen prosessointia python komennoilla ja funktioilla. Luetteloihin lisättiin uusia sarakkeita jotka populoitiin sitten yksittäisillä stringeillä käyttäen loop funktioita. Funktioissa luettiin saman rivin toisesta sarakkeesta tietoa joka sitten määritti kyseisen sarakkeen arvon. Listoja rakennettiin ”data frame” komennolla. Subseteillä voidaan kerätä suuresta määrästä dataa vain olennaiset sarakkeet. Subsetit voidaan konkatenoida yhdeksi uudeksi data frameksi. Listan voi palauttaa takaisin .CSV tiedostoksi.
#
#
#
# <b>Pohdinnat viikosta</b>
#
# Asiaa oli paljon ja varsinkin asennettavaa omalle koneelle. Pythonia olen käyttänyt kyllä aiemmin mutta osa asioista unohtunut. Selvää oli että kurssin suorittaminen vaatii paljon käytännön harjoittelua mikä minusta on vain hyvä asia, koska nimenomaan käytännön osaaminen itseä kiinnostikin.
#
#
#
# ### 3.       Viisi oivallusta
#
# <ol>
# <li>Datatiede yhdistää asioita kommunikaatiosta, tilastotieteestä, ohjelmoinnista ja busineksestä</li>
#
# <li>Crisp-DM on tiedonlouhinnan prosessimalli joka on käytössä nykyään laajasti</li>
#
# <li>Big datassa yhdistyvät voluumi, nopeus ja datan vaihtelevuus</li>
#
# <li>Python Pandas tarjoaa loistavan kirjaston työkaluja suurteen datasettien käsittelyyn</li>
#
# <li>Kaggle tarjoaa hyviä valmiita tietokantoja joilla voi aloittaa harjoittelun ja josta voi löytää harjoitustyötä varten valmiita datasettejä</li>
# </ol>
#
#  ### 4.       Kehitysideat
#
# ·         Tarvittavista Python kirjastoista voisi olla hyvä listaus esim.kurssin verkkosivulla
#
#
#
# ### 5.  Koodirivit viikolta
#
# Jupyter Notebookissa opittua Pandaksen käytöstä
#
# <i>tuodaan Pandas kirjasto käyttöön</i>

# %%
import pandas as pd

# %% [markdown]
# <i>listataan tulokset kansiosta</i>

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 3C9A-00CC
#
#  Directory of C:\Users\jussi\Desktop\Git\joda_2021_diary
#
# 30/04/2021  10.52    <DIR>          .
# 30/04/2021  10.52    <DIR>          ..
# 23/03/2021  14.53    <DIR>          .github
# 26/03/2021  09.41    <DIR>          .ipynb_checkpoints
# 30/04/2021  10.52         1 936 733 Joda-2021_JSA_PAIVAKIRJA.ipynb
# 30/04/2021  10.45    <DIR>          kuvat
# 23/03/2021  14.53             3 175 military tanks.csv
# 23/03/2021  14.53            40 541 read_data.ipynb
# 23/03/2021  14.53                84 README.md
# 23/03/2021  15.08                59 test_file.txt
#                5 File(s)      1 980 592 bytes
#                5 Dir(s)  174 767 644 672 bytes free

# %% [markdown]
# <i>luodaan dataframe csv tiedostosta</i>

# %%
data_frame = pd.read_csv("military tanks.csv")

# %%
data_frame
# Out:
#           Model Name              Origin Country  Crew  Range (km)  \
# 0        MB-3 Tamoyo                      Brazil     4         550
# 1         Leopard C2                West Germany     4         600
# 2   Leopard 2A4M CAN                West Germany     4         400
# 3               VT-4                       China     3         500
# 4           MBT-3000                       China     3         500
# 5            Type 99                       China     3         600
# 6            Type 96                       China     3         400
# 7         Type-90 II             China, Pakistan     3         500
# 8            Type 80  People's Republic of China     4         400
# 9        M-95 Degman                     Croatia     3         700
# 10              T-72                Soviet Union     3         460
# 11            Jaguar                       China     4         540
# 12        Arjun Mk.2                       India     4         400
# ...

# %% [markdown]
# <i>luetaan uuteen df:n ensimmäinen rivi</i>

# %%
first_tank=data_frame.loc[0]

# %% [markdown]
# <i>luetaan uuteen dataframeen ensimmäinen sarake</i>

# %%
model_names = data_frame.loc[:,"Model Name"]

# %% [markdown]
# <i>luetaan seuraavat kiinnostavat sarakkeet</i>

# %%
ranges = data_frame.loc[:,"Range (km)"]

# %% [markdown]
# <i>käytetään iloc komentoa joka lukee rivi/sarake numeroilla</i>

# %%
max_speeds = data_frame.iloc[:,4]

# %%
power_to_weights = data_frame.iloc[:,5]

# %% [markdown]
# <i>luodaan uusi dataframe-1 yhdistelemällä tietoja</i>

# %%
new_data = pd.concat([model_names,max_speeds], keys=['Names','Speeds'])

# %% [markdown]
# <i>luodaan uusi dataframe-2 ynnäämällä kaikki dataframet omaan listaan</i>

# %%
new_data_collection=[model_names,max_speeds,power_to_weights,ranges]

# %% [markdown]
# <i>summataan dataframe-1 sarakkeesta speeds kaikki yhteen</i>

# %%
avg_speeds=sum(new_data['Speeds'])/(new_data['Speeds'].count())

# %%
print("Average top speed:"+str(round(avg_speeds,2))+"km/h")
# Out:
# Average top speed:66.57km/h

# %%
new_data["Speeds"].count()
# Out:
# 18

# %% [markdown]
# _______________________________________________________________________________________________________________________________
#
# # VIIKKO 2
#
# ### Ti 16.03.2021______________________________________________________________________
#
# ### 1.	Osallistuin luennolle ja keräsin aineiston luennolta sekä webbilinkeistä jota luennolla jaettiin. Perjantain harjoituksiin en ehtinyt työkiireiden vuoksi joten jouduin opiskelemaan itsenäisesti aiheesta.
#
# ### 2.	Tiivistelmä luennosta
#
# ### Aiheena: Datan kerääminen ja jalostaminen
#
# - Ryömijöiden ja raapijoiden läpikäynti.
# - Tuotteistettu analytiikka tapahtuu tyypillisesti Business Intelligence (liiketoimintatiedon hallinta) organisaatiossa.
# - ETL prosessi = extract, transform, load (Master data)
#     - Systemaattinen aineisto, pitkät aikasarjat
#     - Tuotteistettua tiedon hyödyntämistä organisaation toiminnassa
#     - Saatavissa laajasti organisaatiossa
#     - Helposti ladattavissa
# - DAD prosessi = discover, access, distill
#     - Samantyyppinen periaate kuin ETL, mutta:
#         -Data-aineisto kerätään hyvin nopeasti
#         -Analyysi tapahtuu nopeasti
#
# <b>Data science workflow</b>
#
# -	Ohjaava analytiikka jolloin datatiede on viety osaksi jonkin järjestelmän toiminnallisuutta
#
# <b>Data-analytiikka liiketoiminnassa</b>
#
# -	Yrityksistä vain noin kolmanneksella on data-analytiikan työkalut käytössä ja dataa hyödynnetään aktiivisesti
#
# <b>Ryömintä</b>
#
# -	Etsitään linkkejä joiden kautta voidaan hakea uusia linkkejä halutuilla parametreilla
#
# <b>Raavinta</b>
#
# -	Kerätään webbisivuilta kiinnostavaa tietoa, joka ollaan löydetty ryöminnän avulla
# -	Raavinnassa on liiketoimintamielessä aina pitää mielessä tekijänoikeusasiat
#
# <b>Tietotyypit</b>
#
# -	Luvut (kokonaisluvut, floatit)
# -	Teksti (stringit)
# -	Boolet (True, False)
# -	Objektit (sekalaista, voi olla myös sisäisiä listoja)
# -	Aikatieto
#
# <b>Data wrangling</b>
#
# -	Tehdään datan siivoaminen käsin josta tekoäly voi tehdä automaattisen rutiinin jota on helppo käyttää jatkossa
#
# <b>Data-aineiston tutkiminen</b>
#
# -	Data-aineisto on hyödyllistä ensin siivota ja järjestää hyvin
# -	Myös datan sisältöä ja rakennetta on hyvä tutkia ennen kuin varsinaisesti mitään aletaan kehittämään
#
# <b> APIt raavinnan ja ryöminnän aputyökaluina </b>
# - API on työkalu joka yksinkertaistaa käyttäjän tekemää työtä suorittamalla taustalla toimintoja kuten monimutkaisia verkkokyselyjä
# - APIt käyttävät tyypillisiä http CRUD metodeja kuten:
#     - GET
#     - POST
#     - PUT
#     - DELETE
#
#
# ### Pe 19.03.2021______________________________________________________________________
#
# Harjoitukseen en ehtinyt tällä kertaa osallistua työkiireiden vuoksi joten jouduin itse käymään omatoimisesti läpi Crawling ja Scraping työkaluja. <b>Python Scrapy</b> kirjasto tarjoaa niihin molempiin työkaluja ja tein harjoituksen läpi mitä esiteltiin Scrapyn sivustolla https://docs.scrapy.org/en/latest/intro/tutorial.html. Scrapya on mahdollista käyttää myös Shellin kautta ja esim. tehdä kokeiluja kyselyistä. Ilmeisesti myös <b>Python Dryscape</b> kirjasto mahdollistaa crawling ja scraping toimintoja. <b>JSON</b> kirjastoa voidaan käyttää Pythonissa käsittelemään järjestettyjä Javascript objektilistoja jotka ovat yleisiä verkkosivujen ja serverin välisessä liikenteessä. JSON työkaluilla voidaan käsitellä Javascript objektinotaatio Pythonille ymmärrettävään muotoon.
#
# Asensin tällä viikolla Visual Studio Code ohjelman ja siihen extension paketin Pythonille. Visual Studio Code on erittäin hyvä työkalu, koska siinä on ennakoiva koodin syöttö.
#
#
# ### 3.	Viisi oivallusta
# <ol>
#     <li>Yritykset käyttävät ETL prosessia hallitakseen Master dataa.</li>
#     <li>DAD prosessi soveltuu datan nopeaan analysointiin ja sitä käytetäänkin ad-hoc tyyppisesti.</li>
#     <li>Ryömintä ja raavinta soveltuvat tiedon hankkimiseen netistä ja yritykset käyttävät sitä aktiivisesti päätöksen teossa.</li>
#     <li>Data wrangling on metodi jolla datan siivoaminen tehdään manuaalisesti jonka aikana tekoäly kehittää tästä rutiinin ja jota voidaan automatisoida datan siivoamiseksi jatkossa. </li>
#     <li>Data aineiston sisältöä ja rakennetta on hyvä tutkia huolellisesti ennen kuin sillä aloittaa varsinaisen työskentelyn</li>
#
# </ol>
#
# ### 4.	Kehitysideat
# ### 5.	Koodirivit viikolta

# %% [markdown]
# Scrapy koodi on lainattu Scrapyn dokumentaatiosta web linkki: https://docs.scrapy.org/en/latest/intro/tutorial.html
#
# <i> Scrapy kirjasto luodaan ensin windowsin CMD:ssä. Luodaan esimerkiksi "TUTORIAL" kansio: </i>
#
# <b> scrapy startproject tutorial</b>
#
# <i> Tämän jälkeen luodaan spider kansioon uusi spider. </i>

# %%
import scrapy

class QuoteSpider(scrapy.Spider):
    name = "quotes"

    def start_requests(self):
        urls = [
            'http://quotes.toscrape.com/page/1/',
            'http://quotes.toscrape.com/page/2/',
        ]

        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)

    def parse(self, response):
            page = response.url.split("/")[-2]
            filename = f'quotes-{page}.html'
            with open(filename, 'wb') as f:
                f.write(response.body)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-5e6636fb95d7> in <module>
# ----> 1 import scrapy
#       2
#       3 class QuoteSpider(scrapy.Spider):
#       4     name = "quotes"
#       5
#
# ModuleNotFoundError: No module named 'scrapy'

# %% [markdown]
# <i>Spider voidaan ajaa scrapy kansion juuresta (siis Tutorial folderista)</i>
#
# <b> scrapy crawl quotes </b>
#
# <i> Scrapy tuo sisällön ja linkit mutta jättää käsittääkseni CSS:n muotoilut pois. Spider ajaa tiedot erillisiin .html tiedostoihin
#
# Scrapylla voidaan myös tehdä suoraan hakuja shellistä. Tällä voidaan testata hakuja ennen varsinaisen koodin kirjoittamista ja varmistaa että oikea data saadaan ulos.
# </i>
#
# <b> scrapy shell "http://quotes.toscrape.com/page/1" </b>
#
# <i> Tämän jälkeen voidaan hakea sivustolta elementtejä käyttäen CSS toimintoa. Vastauksena saadaan SelectorList objekti joka on siis lista.
# </i>
#
# <b> response.css('title::text').getall() </b>
#
# ['Quotes to Scrape']

# %% [markdown]
# _______________________________________________________________________________________________________________________________
#
# # VIIKKO 3
# ### Ti 23.03.2021__________________________________________________________________
#
# GITHUBISSA: InfoTuni Joda2021
#
# ![image.png](attachment:image.png)
#
# Solita, Timo Lehtonen jäänmurtaja liikenteessä hyödynnetty data ja AI
#
# <b>NLP</b> = natural language processing
#
# <b>NLTK</b> python kirjasto puhtaasti NLP:hen
# <i>
# ”
# from nltk.corpus import stopwords
# stopWords = set(stopwords.words('finnish'))
# print(stopWords)
# ”
# </i>
#
# Scikit kirjastosta löytyy NLP toiminnallisuuksia
# GenSim kirjasto jossa NLP tukea
#
# Python VENV virtuaaliympäristö
# Hox! Estetään virtuaaliympäristön kopiointi Githubiin
#
# !Tee päiväkirjasta Public
# !Asenna GIT koneelle päiväkirjan päivittämistä varten
#
# ### 1.	Osallistuin luennolle ja keräsin aineiston luennolta sekä webbilinkeistä jota luennolla jaettiin.
#
# ### 2.	Tiivistelmä luennosta
# ### Aiheena: Koneoppimisen periaatteet
#
# <b>Workflow</b>
#
# - Keskeiset tavat: <b>Ohjattu ja ohjaamaton</b> oppiminen
# - Siirretään rutiinitoimintojen suorittamista ihmiseltä koneelle
# - Dataa käytetään hyödyksi jolla luodaan koneoppimismalli
#     - se kuinka hyvin koneoppimismalli toimii on hyvin riippuvainen siitä millaista dataa sille on syötetty!
#     - roskaa sisään = roskaa ulos
# - Iteratiivinen prosessi
# - Koneoppimisalgoritmin alustaminen, jossa KAKSI lähestymistapaa
#     - Ohjattu:
#         - Ennustettavan muuttujan määrittäminen (Label)
#         - Kehitetään algoritmi joka pystyy ennustamaan datasta
#         - Raakadatasta erotetaan piirteitä => ennustavia muuttujia
#         - Piirteiden suunnittelu on keskeinen osa ohjatun  oppimisen kehitystyötä
#     - Ohjaamaton:
#         - Määritellään tavoite eli Label
#         - Datasetti mistä tulee oppia
#         - Annetaan ohjaamaton oppimisalgoritmi etsiä ennustavat muuttujat
#         - Arvoidaan mallin suorituskyky
#
# <b>Piirteiden erotteleminen ja jalostaminen</b>
#
# - Ikään kuin liiketoiminnassa KPI:t (key performance indicators)
# - Jatkuvia muuttujia, binäärisiä (0/1), aika/aikaleimat
# - Hyvä kuitenkin pitää mielessä, että ”Raaka-dataa” ei ole olemassa
#     - Tarkoittaa että datan valinta ja kerääminen on aina subjektiivinen toiminta ja tehty yhdestä näkökulmasta
#     - Dataan pitää täten aina suhtautua kriittisesti ja sitä pitää tutkia ja vertailla esim. muuhun dataa
# - Miten voidaan valita laadukkaat piirteet jotka parantavat algoritmin suorituskykyä?
# - Merkityksellistä myös se että algoritmi on ymmärrettävä
# - Koneoppimisalgoritmiä voidaan kehittää pääasiassa kahdella keinolla
#     - Algoritmiä optimoimalla
#     - Piirteitä jalostamalla
# - Aineistoa kuvaavia muuttujia joilla luodaan malleja
#
# <b>Aineiston luokittelu (Pythonilla)</b>
#
# - Esimerkkinä yrityksen asiakaspoistuma: poistunut asiakas / nykyinen asiakas
# - Aineiston esikäsittelyä "feature engineeringiä", alla esimerkkejä mitä datalla voidaan tehdä tässä vaiheessa
#     - luodaan tietokoneelle selkeitä muuttujia käytettävissä olevista muuttujista yhdistelemällä,
#     - muuttamalla esim. string dataa binaareiksi,
#     - tai esim. formatoimalla float arvot integereiksi,
#     - poistetaan tarpeettomia rivejä
#     - käsitellään tyhjät rivit ja valitaan niiden käsittely strategia
# - Tutkitaan aineistoa, mitä se sisältää mitä ei sisällä
# - Tehdään validointi setti, testisetit
# - Luokitellaan aineistoa
# - Scikit kirjastolla
#
# <b>Muuta</b>
#
# Dataa on nykyään paljon enemmän tarjolla joka on mahdollistanut tekoälyn ja koneoppimisen soveltamisen paljon laajemmin. Ala on ollut olemassa jo vuosikymmeniä mutta usein ongelmana on ollut datan puute ja algoritmit ovat kehittyneet vasta viime aikoina.
# Käytiin läpi NLP työkaluja tekstin analysointiin Pythonin NLTK kirjastolla. Sanojen frekvenssiä, sentimenttiä (esim.positiivinen/negatiivinen sentimentti).
# <i>Lineaariregresio</i> ehkä yksinkertaisin esimerkki koneoppimisen keinoista. Tavoitteena on löytää kahden muuttujan välille lineaarinen yhteys. <i>Tavoitteeksi koneelle asetetaan minimioida virhe pistejoukon ja siitä piirrettävän suoran välillä</i>. Koneoppimisen tuloksena on suora, jonka kone ennustaa pistedatasta.
# Monimuuttujaregressio on jo tästä kehittyneempi algoritmi.
#
# ### Pe 26.03.2021__________________________________________________________________
#
# Harjoituksissa käytiin läpi laajan datasetin luokittelua Scikit learn työkaluilla. Luotiin myös testicase jolla voidaan hakea parhaat metodit/luokittelijat varsinaiseen datasetin myöhempään analyysin. Tässä datasetissä pyritään ennustamaan Loan status parametria muilla parametreillä. Perehdytiinn sklearn kirjastoon Pythonissa.
#
# Kirjastot mitä harjoituksessa käytettiin
# ![image-11.png](attachment:image-11.png)
#
# <i> listaa ensimmäiset 5 riviä dataframesta</i>
# <br>df.head()
#
# <i> listaa setin columnit </i>
# <br>df.info()
#
# <i> poistetaan tarpeettomia rivejä setistä</i>
# ![image-2.png](attachment:image-2.png)
#
# <i> poistetaan NaN rivit datasta </i>
# <br>data = data.dropna()
#
# <i> sklearn.impute.SimpleImputer kirjastolla voidaan käsitellä tyhjiä soluja datassa; voidaan esimerkiksi korvata tyhjien solujen arvot koko sarakkeen keskiarvolla, tai esim. arvolla 0
#     </i><br>
# ![image-3.png](attachment:image-3.png)
#
# <i><B>TAVOITE ATTRIBUUTTI MITÄ TESTISSÄ YRITETÄÄN ENNUSTAA: "LOAN STATUS". </B><BR>Esimerkki yksinkertaisista feature engineering operaatioista, jossa muunnetaan string atribuutti booleksi:</i>
# ![image-4.png](attachment:image-4.png)
#
# <i><b> DATA SETIN NORMALISOINTI! Tässä vaiheessa luodaan 3 erilaista datasetin käsittelijää: normalisoitu, MinMax ja ei-normalisoitu </b><br> normalisointi tärkeää jos halutaan tehdä ennustajaa esim. SGDC classifierilla </i>
# ![image-5.png](attachment:image-5.png)
#
# <i> hox! axis määrittää tehdäänkö normalisointi riveille vai sarakkeille </i>
#
# <i> MiMaxScaler() metodilla voidaan normalisoida arvot suurimman suhteen välille 0-1 </i>
#
# <i> Mallille valitut parametrit <br>
# kuvassa ei näy mutta data_size=0.25 eli koulutukseen käytetään vain 25% koko aineistosta</i>
# ![image-7.png](attachment:image-7.png)
#     <i>Alla vastaavanlainen esimerkki sivulta: https://www.datatechnotes.com/2020/09/sgd-classification-example-with-sgdclassifier-in-python.html </i>
# ![image-10.png](attachment:image-10.png)
#
#
# <i><b> Mallin kouluttaminen valituilla parametreillä. Tässä vaiheessa mallille pyritään hakemaan sopiva luokittelumetodi kolmesta vaihtoehdosta </b></i>
# ![image-6.png](attachment:image-6.png)
#
# <i> Testeissä MinMax tuotti parhaan tarkkuuden ja luokittelumetodit ovat hyvin lähellä toisiaan, niistä SVC():n tuottaessa pienimmän virheen </i>
# ![image-8.png](attachment:image-8.png)
#
# <i> käytetään MinMax metodia sekä LogisticRegression() luokittelumetodia koko dataframelle</i>
# ![image-9.png](attachment:image-9.png)
#
#
#
# ### 3.	Viisi oivallusta
#     1. Koneoppimisen menetelmät voidaan karkeasti luokitella:ohjaamattomaan ja ohjattuu oppimiseen
#     2. Koneoppimismallit tarvitsevat paljon dataa luodakseen mallin ja datan laadulla on hyvin suuri merkitys siihen mitä saadaan ulos
#     3. Ohjatussa oppimisessa tärkeää on määrittää ennustettava muuttuja ja sitä ennustavat muuttujat
#     4. Ennustavia muuttujia joudutaan tyypillisesti muokkaamaan ja muotoilemaan jotta ne soveltuvat koneoppimismalliin ja tätä prosessia kutsutaan Feature Engineeringiksi
#     5. Koneoppimisalgoritmia voidaan kehittää pääasiassa kahdella tavalla: piirteitä jalostamalla, algoritmia optimoimalla
# ### 4.	Kehitysideat
#     tämän viikkoinen harjoitus jäi hieman vaikeaselkoiseksi, ehkä olisi ollut hyvä kuvata mitä vaihetta nyt käydään läpi CRISP-DM prosessissa ja mitä lopputulosta tavoitellaan
# ### 5.	Koodirivit viikolta

# %%
df.info() #dataframen kolumniotsikot
df.head() #dataframen viisi ylimmäistä riviä
df.iat[1,1] #dataframen tietyn solun tietokysely
df.iloc[0] #dataframen tiety rivin kysely
df_cleaned=df.dropna(axis=0,how="all") #siistitään tyhjät rivit datasetistä, kun rivillä ei ole mitään tietoa
sklearn.impute.SimpleImputer # tällä komennolla voidaan muokata helposti tyhjien solujen arvoja

# %% [markdown]
# _______________________________________________________________________________________________________________________________
#
# # VIIKKO 4
# ### Ti 30.03.2021__________________________________________________________________
#
#
# ### 1.	Osallistuin luennolle ja keräsin aineiston luennolta sekä webbilinkeistä jota luennolla jaettiin. Kuuntelin myös perjantain harjoitukset
# Tiistaina 06.04. ei luentoa.
# <i>Python Jinja</i> kirjasto webbisivun kojelaudan visuaaliseen rakentamiseen.
# <i>Python Streamlit</i> kirjasto myös hyvänä visualisoinnin. Vuorovaikutteiset elementit.
#
# ### 2.	Tiivistelmä luennosta
# ### Aiheena: Data-analytiikan prosessi sekä mittarit onnistumiseen
#
# Tavoitteena harjoitustyöhön orientoituminen ja missä järjestyksessä siihen tulisi käydä käsiksi datatieteen keinoin. CRISP-DM prosessi johdattaa hyvin siihen miten dataa kannattaa lähteä prosessoimaan.
# ![image.png](attachment:image.png)
# CRISP-DM prosessi. Web-linkki: https://towardsdatascience.com/why-using-crisp-dm-will-make-you-a-better-data-scientist-66efe5b72686
#
#
# Mittarit analytiikan onnistumiseen<br>
# <b>Quality</b><br>
#     - voidaan varmistua että päätelmät ovat johdonmukaisia ja noudattavat samaa linjaa, keräämällä esim. NLP:n keinoin asiakkaiden tunnetiloja ja avainsanoja yhdistelemällä<br>
# <b>Speed</b><br>
#     - suurta määrää dataa voidaan työstää nopeasti vrt. esim. haastattelututkimukset<br>
# <b>Robustness</b><br>
#         - suuresta määrästä dataa voidaan tehdä järkeviä päätelmiä datatyökalujen avulla<br>
#     - periaatteessa samat toiminnot ovat tehtävissä uudelleen toisena ajankohtana ja voidaan saada luotettavia tuloksia
#
# <b>AirBnB alustantarjoaja majoituspalveluissa</b>
# Millaisia analyyseja AirBnB voisi tehdä datan perusteella?
# - kerätä majoittajilta palautetta majoittujista jonka perusteella heidät voidaan luokitella ja esimerkiksi määrittää majoittumisen säännöt
# - kerätä majoittujilta palautetta jotta asunnot ovat laadukkaassa kunnossa ja erityisesti hygieniasta on pidetty huolta
# - analysoida miten suosittuja korkean siisteystason asunnot ovat verrattuna tavallisen siisteystason asuntoihin, onko Covid vaikuttanut paljon tähän suosituimmuuteen
# - palautteita voidaan analysoida myös NLP:n keinoin keräämällä eniten esiintyneitä sanoja ja niihin liittyviä tunnetiloja ja määrittää tämän perusteella vaikkapa majoittujien käyttäytymisestä top10 ongelmakohdat
#
# AirBnB kerää valtavasti dataa jolla se orkesteroi koko toimintaa ja businessta
#
# <b><i>Programmable WEB</i> tarjoaa valtavasti ohjelmoitavia rajapintoja APIt (yli 24000)
# esim. Open Street Maps</b>
#
# <b>Aineiston rikastaminen</b>
# Voidaan yhdistellä dataa eri lähteistä. Esimerkiksi AirBnB asunnot vs. kahvilat/ravintolat.
#
# <b>Luokittelu</b>
# Scikit learn kirjastolla voidaan tehdä luokitteluja datalle (myös ohjaamaton oppiminen)
#
# ### Pe 09.04.2021__________________________________________
# Perjantain harjoituksen kirjastot
# ![image-2.png](attachment:image-2.png)
#
#
# Pandaksella on helppo poimia halutut sarakkeet isommasta datasetista. Muuttujaa voidaan refereroida pandaksessa suoraan (hox! älä käytä välilyöntejä muuttujassa)
# Kunkin sarakkeen muotoilua ja esimerkiksi formaattia on helppo muokata pandaksen komennoilla kuten <i>to_numeric</i>.
# ![image-4.png](attachment:image-4.png)
# <i>Unique()</i> komennolla voidaan kysyä tietyn muuttujan kaikki arvot.
#
# Host response time <i>Str</i> arvot korvataan numeerisilla arvoilla käyttäen <i>preprocessing.LabelEncoder()</i> metodia. Voidaan tarkastaa le.classes_ metodilla mitkä attribuutit saivat minkäkin numeroarvon.
# ![image-5.png](attachment:image-5.png)
#
# Lineaarinen regressiomalli voidaan hakea datalle sklearn kirjaston metodeilla. Cross validation työkalulla voidaan jakaa data setti testisetteihin sekä training setteihin. "cv" jakaa setin osiin. Pyyritään nyt ennustamaan "review_scores_rating" arvoa muilla aroilla.
# ![image-6.png](attachment:image-6.png)
#
# Korrelaatiota tutkitaan seuraavaksi. Näyttäisi että korrelaatio on heikko ennustamaan <i>review_scores_rating</i> arvoa.
# ![image-9.png](attachment:image-9.png)
#
# Korvataan datasetissä nolla-arvot mediaaniarvolla
# ![image-10.png](attachment:image-10.png)
#
# Seuraavassa testissä käytettiin kahden muuttujan sijasta yhdeksää ja saatiin huomattavasti parempi korrelaatio <i>review_scores_ratingiin</i>.
#
#
#
# ### 3.	Viisi oivallusta
#     1. Analytiikan onnistumisen mittarit Quality, Speed, Robustness
#     2. Ohjelmoitavia rajapintoja eli API:ja löytyy valtavasti Programmable web sivustoilta.
#     3. Perjantain harjoituksissa opittiin tekemään usean muuttujan regressiomallia
#     4. tekstimuotoisten muuttujien muuttaminen numeerisiksi
# ### 4.	Kehitysideat
# ### 5.	Koodirivit viikolta
#     1. pd.to_numeric #varmistetaan että datasetti on numeerista dataa eikä objekteja
#     2. df.host_response_rate #voidaan viitata dataframen johonkin nimettyyn sarakkeeseen)
#     3.df.apply(preprocessing.LabelEncoder().fit_transform) #voidaan muuttaa tekstiarvot numeerisiksi)
#     4.le.classes_ # voidaan tarkistaa jälkikäteen mitkä numeeriset arvot vastaavat mitäkin tekstiarvoa
#     5. lr = linear_model.LinearRegression() # voidaan pohjustaa malli mitä käytetään
#     6. predict = cross_val_predict(lr, X, Y, cv=10) #voidaan hakea lineaarinen regressiomalli testisetille joka on jaettu cv:llä 10 osaan

# %% [markdown]
# _______________________________________________________________________________________________________________________________
#
# # VIIKKO 5
# ### Ti 13.04.2021__________________________________________________________________
# "Corpus" = suuri tekstimassa
#
# Solitan data akatemia kurssi. kesto 4-6kk, järjestetään yleensä 2 kertaa vuodessa.
#
#
# ### 1.	Osallistuin vierailuluennolle ja keräsin aineiston luennolta sekä webbilinkeistä jota luennolla jaettiin. Kuuntelin myös perjantain harjoitukset
#
#
# ### 2.	Tiivistelmä luennosta
# ### Aiheena: Luonnollisen kielen analytiikka NLP
#
# Jodassa järjestettiin ensimmäistä kertaa vierailuluento, Solitalta Teemu Mikkonen ja Timo Lehtonen. Alussa mietittiin miten dataprojektin performanssia tai onnistumista voidaan arvioida ja mitä uskalletaan luvata asiakkaalle. Esitellään lunnollisen kielen analyysia teollisuudessa.
#
# Käytetään esitystä Google Colabista käsin. Colab näyttäisi olevan mielenkiintoinen tapa esittää dataprojekteja pilvessä.
# - ilmainen googlen ylläpitämä Notebook
# - helppo jakaa koodia
# - saatavilla myös laskentatehoa (GPU ja jopa TPU (Tensor processing units))
#
# Solitalla paljon tarjontaa dataosaamisen ympärillä. Yli 200 dataosajaa.
#
# Esiteltiin NLP data-analyysiä mitä oltiin tehty ministerien antamaan kirjallisiin vastauksiin analysoimalla vastauksia NLP:n keinoin.
#
# <b>NLP</b>
# - datalähteenä on luonnollinen kieli
# - luonteeltaan rakeenteentonta
# - tärkeää data-analyysissa esikäsittely ja piirteiden erottelu
# - käyttökohteita mm. chatbotit, automaattiset konekäännökset, tekstin luokittelu ja analysointi
# - NLP on usein linkitetty johonkin muuhun data/koneoppimisratkaisuun
#
# Stopwords = ovat sanoja jotka eivät tuo mitään lisäinformaatiota dataan
#
# Helppo tapa Pythonilla sisällyttää yksinkertainen funktio for looppiin
# ![image.png](attachment:image.png)
#
# Datasetistä voidaan poistaa näppärästi toistuvat rivit <i>drop_duplicates()</i> komennolla
# ![image-2.png](attachment:image-2.png)
#
# Ministeriöiden datapisteiden määrästä voidaan nähdä että niissä on selvä epäsuhta. Voidaan olettaa että malli oppii tunnistamaan paremmin niiden ministeröiden vastaukset joissa paljon vastauksia.
#
# ![image-3.png](attachment:image-3.png)
#
# Keinoja tasapainottaa dataapisteiden määrää settien välillä ovat: yliotanta tai aliotanta
# - poistetaan aliotannalla yksinkertaisesti rivejä datasta
# - yliotannassa voidaan luoda keinotekoisesti datapisteitä lähelle esim. keskiarvoa
#
# Esikäsittely
# - parantaa opetusdatan laatua
# - vähentää kohinaa
# - muunnetaan data muotoon jota voidaan käyttää opetukseen (numeerisiksi tai esim. vektoreiksi)
#
# Kyseissä esimerkissä sanat vektoroidaan esiintymismäärän ja frekvenssin suhteella.
#
# Esimerkki Regexin käytöstä sanojen käsittelyssä. Ensimmäisessä komennossa poistetaan kaikki muu paitsi kirjaimet ja numerot.
# ![image-4.png](attachment:image-4.png)
#
# <i>Voikko</i> kirjastolla voidaan muuntaa suomen kielen sanoja perusmuotoon.
#
# Esimerkissä esitellään apufunktio. Yksinkertaisia for looppeja ja esimerkki miten poistetaan useita sarakkeita.
# ![image-5.png](attachment:image-5.png)
#
# Fasttext kirjasto käsittelee sanoja niiden kontekstissa ja antaa niille vektoriarvon sen perusteella. Suomen kielelle Turku NLP mutta ovat kohtuu raskaita käyttää.
#
# NLTK ja Voikko kirjastot ovat parhaita käyttää yhdessä. NLTK:lla tehdään kielelle lähinnä esiprosessointia. Voikko selkeästi suomen kielen prosessori.
#
# Epochin käyttö mallille: liian suuri iteraatio määrä voi johtaa mallin ylifittaamiseen eli malli erikoistuu liikaa datasetille.
#
#
#
# ### Pe 16.04.2021__________________________________________
#
#
# ### 3.	Viisi oivallusta
#     1. Luonnollisen kielentunnistuksen työkaluja löytyy myös suomen kiellelle kuten Voikko
#     2. Google Colab on ilmainen palvely jossa Notebookkeja voidaan helposti rakentaa data-analyysia varten, joka myöhemmin jaettavisissa helposti.
#     3. Fasttext kirjastolla voidaan antaa vektoriarvot sanoille niiden kontekstin perusteella
#     4. NLTK kirjasto soveltuu erityisen hyvin kielen esiprosessointiin mutta se ei korvaa esim. Voikkoa, jolla voidaaan taas kielen rakennetta muuttaa.
#     5. Ylifittaamisen vaara. Kun mallia opetetaan, liian suuri iteraatioiden määrä voi olla haitallista, koska malli erikoistuu liikaa testisetille.
#
# ### 4.	Kehitysideat
#     - vierailuluento oli hyvä!
# ### 5.	Koodirivit viikolta
#     1. df.read_csv('nn.csv').drop_duplicates() # voidaan pudottaa duplikaattirivit datasta
#     2. datasetti = [ i.split("/")[0] for i in datasetti] # voidaan suorittaa yksinkertainen for looppi yhdellä rivillä koodia
#     3. sana = re.sub("^A-Za-z0-9ÄäÖö-]+", "", sana) # regexiä, korvataan tyhjällä merkillä kaikki muu paitsi kirjaimet, numerot ja ääkköset

# %% [markdown]
# _______________________________________________________________________________________________________________________________
#
# # VIIKKO 6
# ### Ti 20.04.2021__________________________________________________________________
#
#
#
# ### 1.	Osallistuin luennoille ja keräsin aineiston luennolta sekä webbilinkeistä jota luennolla jaettiin. Kuuntelin perjantain harjoitukset ja kirjailin muistiinpanot
#
#
# ### 2.	Tiivistelmä luennosta
# ### Aiheena: ohjaamattoman oppimisen menetelmät
#
# <b>Esimerkkkinä ostoskorianalyysi</b>
# Tutkitaan ihmisten ostoskoreja ja ostosten välisiä riippuvuuksia.
#
# <b>Esimerkkinä verkostoanalyysi</b>
# Marvel hahmojen esiintyminen elokuvissa. Verkostoanalyysilla voidaan tutkia hahmojen sosiaalisen verkoston rakennetta.
#
# <b>Ryvästäminen eli klusterointi</b>
# K-means ryvästäminen tulee olemaan yhtenä aiheena joka on ryvästämisen yksi menetelmä. Pyritään tunnistamaan kokonaisuuksia datasta ja luokittelemaan näin ollen data ryppäisiin.
#
# <b>Työkierto ohjaamattomassa oppimisessa</b>
# 1. raaka -data
# 2. piirteiden erotus ==> saadaan piirrevektori
# 3. käytetään mallia joka opetettu aiemmin
# 4. käytetään ennustinta vaikkapa k-means menetelmällä
# 5. voidaan sijoittaa uusi havainto(asiakas) prosessiin tiettyyn ryhmään.
#
# Ohjaamattomassa oppimisessa voidaan tuottaa labeleita myös käyttäjien (asiakkaiden) toimesta. Esim.toivelistalle lisääminen verkkokaupassa.
#
# Visualisoinnin kirjasto <i>Bokeh</i>. Voidaan luoda interaktiivisia ja dynaamisia visualisointeja Pythonilla.
#
# <b>Normalisointi</b> on tärkeää datalle jotta datalle voidaan tehdä luokittelua. Normalisoinnilla skaalataan kaikki arvot samalla skaalalle ja tällä voidaan erottaa datasta ne muuttujat joilla on suuri vaikutus luokan määräytymiseen.
#
# <b>K-means menetelmässä</b> täytyy aina ennustaa <b>klustereiden</b> määrä. Klusterien määrän "oikeata" arvausta voi arvioida sillä kuinka suuri varianssi pisteiden etäisyyden osalta on klusterissa. Haetaan käyrältä se klusterien lukumäärä jossa muutoksen suuruus pienenee voimakkaimmin.
#
# <b>Luonnollisen kielen analyysi ja aihemallinnus</b>
# Tietyissä aiheissa tietyt sanat esiintyvät useammin kuin toiset, jolloin tällä voidaan ennustaa aihetta sanojen perusteella. <b>Dokumentti-termi matriisi</b> on matemaattinen matriisi joka kuvaa termien frekvenssiä joka esiintyy dokumenttikokoelmassa.
#
# <b>Gensim</b> kirjastolla voidaan tehdä tekstin semanttista (merkityksen) analyysia. Käyttää tilastollista koneoppimisen menetelmää. Semanttinen analyysi on haastavaa ja oikeaan osuminen voi olla hyvin epävarmaa. Pitää esim. kysyä edustaako teksti elokuvan tyylilajia riittävän hyvin.
#
# <b>Ohjaamattomassa oppimisessa</b> joudutaan kuitenkin suunnittelijan toimesta ohjaamaan prosessia esim. datan haarukoinnin osalta ja analyysimetodien osalta. Siinä mielessä ei voida puhua mitenkään autonomisesta prosessista, vaan on suunnittelijan toimesta ohjattua metodien valinnan myötä.
#
# ### Pe 23.04.2021__________________________________________
#
# Tänään käytiin läpi ostoskorianalyysia Python ympäristössä.
#
# Datan kuvailuun tehoksas komento on <i>df.describe('all')</i>, jolla voidaan saada datasta irti instanssien määrää, keskiarvoa, hajontaa, min/max arvot jne.
#
# <img src="kuvat/L61.png"/>
#
# Yksittäisten instanssien määrää jollakin atribuutilla voidaan kuvata kuvata <i>value_counts</i> komennolla histogrammissa. Bins=50 määrittelyllä voidaan rajata instanssien määrä top-50.
#
# <img src="kuvat/L62.png"/>
#
# Tuotteet ja niiden description voidaan järjestää laskunumeron mukaan komennolla <i>groupby</i>. <i>.agg(list)</i> pandas yhdistää dataframen
#
# <img src="kuvat/L63.png"/>
#
# Python lambda funktioon syötetään mikä tahansa määrä argumentteja ja se voi pitää sisällään vain yhden lausekkeen.
#
# <img src="kuvat/L64.png"/>
#
# Toinen yksinkertainen esimerkki lambda funktiosta https://www.w3schools.com/. Palauttelua mieleen.
#
# <img src="kuvat/L65.png"/>
#
# Lambda funktiota kutsutaan <i>.apply(lambda_funktio)</i> komennolla
# <img src="kuvat/L66.png"/>
#
# Käytetään apriori työkaluja, jolla määritetään tuotesetit ja niiden säännöt. <i>%time</i> komennolla voidaan Notebookissa pyytää Python ottamaan aikaa komennon ajosta
# <img src="kuvat/L67.png"/>
#
# Apriori palauttaa item setit ja säännöt. Palautteessa on myös sisällä konfidenssi
# <img src="kuvat/L68.png"/>
#
# Top 10 tuoteyhdistelmätä haetaan ja niiden konfidenssi esitetään aineistosta jälleen omalla lambda funktiolla
# <img src="kuvat/L69.png"/>
#
# Network kuvaajaa varten luodaan <i>all_rules</i> lista. <i>rules</i> Listasta käydään läpi vain viisi ensimmäistä sääntöä, eli testaan aluksi. Network kuvaajaan lisätään yksittäiset solmut <i>.network.add_node</i> komennolla
#
# <img src="kuvat/L610.png"/>
#
# Seuraavaksi piirretään varsinainen verkostokuvaaja nx määrittelyillä.
# <img src="kuvat/L611.png"/>
#
# Määritellään kuvaaja loppuun.
# <img src="kuvat/L612.png"/>
#
#
#
# ### 3.	Viisi oivallusta
#     1. Data-analytiikassa ryvästäminen on keskeisessä roolissa kun halutaan tutkia mitä yhteistä muuttujilla on
#     2. Verkostoanalyysit ja ostoskorianalyysit ovat jokapäiväisiä esimerkkejä ryvästämisen hyödyntämisestä
#     3. Ryvästämiseen on useita menetelmiä mutta niistä yhtenä esimerkkinä on K-means menetelmä
#     4. Datan normalisointi on tärkeää jotta voidaan nähdä mitkä muuttujat vaikuttavat eniten, normalisointi tulee tehdä vasta kun data on splitattu opetus ja testisetteihin
#     5. Ohjaamattomassa oppimisessa analyytikolla on silti suuri rooli, koska hän tekee valintoja muuttujista ja käytetyistä metodeista (esim. K-means sen sijaan että jokin muu)
#
# ### 4.	Kehitysideat
# ### 5.	Koodirivit viikolta
#     1. Voidaan visualisoida histogrammissa muuttujia
# <img src="kuvat/L614.png"/>
#
#     2. value_counts, jolla voidaan kysellä instanssien määrää muuttujalta
#     3. groupby, jolla voidaan järjestää yhdet muuttujat jonkun toisen mukaan
#     4. lambda funktiot hyvänä mieleen palatuksena miten ne toimivat
#     5. %time komennolla saadaan Notebookissa laskemaan käytetty aika funktion ajoon

# %% [markdown]
# # VIIKKO 7
# ### Ti 27.04.2021__________________________________________________________________
#
#
#
# ### 1.	Osallistuin luennoille ja keräsin aineiston luennolta sekä webbilinkeistä jota luennolla jaettiin.
#
# ### 2.	Tiivistelmä luennosta
# ### Aiheena: Visuaalinen analytiikka
#
# Periaatteessa yksi ja sama termi joka käsittää nämä kaikki:
# - Informaation visualisointi
# - Datan visualisointi
# - Visuaalinen analytiikka
#
# Tavoitteena auttaa analysoijaa tunnistamaan merkityksiä ja auttaa analysoijaa tekemään johtopäätöksiä ja havaintoja. Koneoppimista voidaan hyödyntää visualisoinnissa, kun jalostetaan aineistoa esim.tunnistetaan ryppäitä. Visualisoinnissa täytyy tarkasti harkita piirteiden koodamiseen mahdollisuuksia sellaiseen muotoon että ne voidaan visualisoida hyvin.
#
# <b>Eksploratiivisuus</b>
# On käytännössä lähestymistapa dataan. Esimerkiksi että osaa asettaa oikeanlaisia kysymyksiä liittyen dataan ja että dataa tutkitaan riittävän pitkälle ennen johtopäätöksien tekemistä
#
# <b>Visuallisoinnilla</b> on kaksi keskeistä sovellusta datatieteessä
# - eksploratiivinen eli kartoittava analytiikka: lähtödatan tutkiva kartoittaminen
# - kommunikointi: tulosten ja välivaiheiden välittäminen
#
# <b>Eksploratiivinen analytiikka</b>
#
# Tietojohtamisen DIKW-pyramidi.
# <img src="kuvat/L71.png" />
# Linkki: https://en.wikipedia.org/wiki/DIKW_pyramid
#
# Visualisointia tehdään joko datan ja informaation välissä, tai informaation ja tiedon välissä. Myös takaisinkytkentää tapahtuu koska tietämyksellä voidaan vaikuttaa datan laatuun mitä analysioidaan.
#
# Hyvä kysymys mikä on datan, tiedon ja tietämyksen välinen ero.
#
# <b>Datan visualisointi (Fry, 2008)</b>
# 1. Hanki
# 2. Pura
# 3. Suodata
# 4. Louhi
# 5. Kuvaile
# 6. Jalosta
# 7. Vuorovaikuta
#
# Käytiin läpi esimerkkejä datan visualisoinnista missä oli tehty jotakin selkeitä virheitä. Visualisointia olisi hyvä testata käyttäjillä ennen julkaisua jotta saadaan käsitys siitä ymmärtävätkö muut sitä.
#
# Visualisoinnin ja käytettävyyden suunnitteluun on nykyään metodeja jotka edesauttavat kehittämään hyviä applikaatioita alusta alkaen. Aikaisemmin vallalla ollut tee-testaa-kehitä metodi ei ole enää suosiossa.
#
# Hyviä visualisointitapoja on esitelty esimerkiksi sivulla:
# https://datavizproject.com
#
# Visuaalinen rajapinta tulee merkitykselliseksi, jossa käyttäjä ei ole suoraan tekemisissä datan kanssa vaan se visualisoidaan hänelle rajapinnan kautta. Tästä esimerkki IBM Watson joka kyselee käyttäjältä mitä hän haluaa nähdä datasta ja tuottaa sen jälkeen visualisoinnin joka vastaisi käyttämään kysymykseen.
#
# Streamlit.io on alusta jolla voidaan luoda web appeja todella nopeasti.
#
#
# ### 3.	Viisi oivallusta
#     1. Visualisointia tarvitaan jotta voidaan tehdä järkeviä johtopäätöksiä ja tunnistamaan merkityksiä
#     2. Eksploratiivisuus on lähestymistapa data käsittelyyn. Tärkeässä osassa on dataan perehtyminen syvällisesti ja datan esittäminen eri muodoissaan.
#     3. Visualisoinnissa tärkeässä roolissa myös datan esikäsittely ja muokkaaminen jotta se voidaan visualisoida järkevästi.
#     4. Tietojohtamisen DIKW pyramidissa visualisointi osuu sekä datan&informaation väliin että informaation&tiedon väliin
#     5. Visualisoinnilla on kaksi tärkeää sovellusta datatieteessä: eksploratiivinen analytiikka ja kommunikointi

# %% [markdown]
# END
